# %% [markdown]
# ### Task 1

# %%
import pandas as pd

# %%
insurance_df = pd.read_csv('data/insurance.csv')
print('Shape: ',insurance_df.shape)
print('Column Names: ', insurance_df.columns.to_list())
print('__________________________________________')
print(insurance_df.head())
# Out:
# Shape:  (1338, 7)
# Column Names:  ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
# __________________________________________
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# `insurance_df` describes insurance customers, describing them with mulitple features and listing the charges for each.

# %%
grad_df = pd.read_csv('data/grad.csv')
print('Shape: ',grad_df.shape)
print('Column Names: ', grad_df.columns.to_list())
print('__________________________________________')
print(grad_df.head())
# Out:
# Shape:  (400, 4)
# Column Names:  ['admit', 'gre', 'gpa', 'rank']
# __________________________________________
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4

# %% [markdown]
# `grad_df` seems to be a list of students who applied to grad school

# %%
bike_sharing_df = pd.read_csv('data/bike_sharing.csv')
print('Shape: ',bike_sharing_df.shape)
print('Column Names: ', bike_sharing_df.columns.to_list())
print('__________________________________________')
print(bike_sharing_df.head())
# Out:
# Shape:  (731, 16)
# Column Names:  ['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']
# __________________________________________
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# ...

# %% [markdown]
# `bike_sharing_df` describes each day that bikes were rented/shared. Each day records weather factors and amounts of bikes used.

# %% [markdown]
# ### Task 2

# %%
# Client A
print(insurance_df['charges'].head(10))

print(insurance_df['charges'].unique())
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# 5     3756.62160
# 6     8240.58960
# 7     7281.50560
# 8     6406.41070
# 9    28923.13692
# Name: charges, dtype: float64
# [16884.924   1725.5523  4449.462  ...  1629.8335  2007.945  29141.3603]

# %% [markdown]
# This target column contains each customer's insurance charge.
# This is a regression problem

# %%
# Client B
print(grad_df['admit'].head(10))

print(grad_df['admit'].unique())
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    1
# 9    0
# Name: admit, dtype: int64
# [0 1]

# %% [markdown]
# This is a binary column describing if the student was admitted or not.
# This is a binary classification problem

# %%
# Client C
print(bike_sharing_df['cnt'].head(10))

print(bike_sharing_df['cnt'].unique())
# Out:
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# 5    1606
# 6    1510
# 7     959
# 8     822
# 9    1321
# Name: cnt, dtype: int64
# [ 985  801 1349 1562 1600 1606 1510  959  822 1321 1263 1162 1406 1421
#  1248 1204 1000  683 1650 1927 1543  981  986 1416 1985  506  431 1167
#  1098 1096 1501 1360 1526 1550 1708 1005 1623 1712 1530 1605 1538 1746
#  1472 1589 1913 1815 2115 2475 2927 1635 1812 1107 1450 1917 1807 1461
#  1969 2402 1446 1851 2134 1685 1944 2077  605 1872 2133 1891  623 1977
#  2132 2417 2046 2056 2192 2744 3239 3117 2471 2703 2121 1865 2210 2496
#  1693 2028 2425 1536 2227 2252 3249 3115 1795 2808 3141 1471 2455 2895
#  3348 2034 2162 3267 3126  795 3744 3429 3204 3944 4189 1683 4036 4191
#  4073 4400 3872 4058 4595 5312 3351 4401 4451 2633 4433 4608 4714 4333
#  4362 4803 4182 4864 4105 3409 4553 3958 4123 3855 4575 4917 5805 4660
#  4274 4492 4978 4677 4679 4758 4788 4098 3982 3974 4968 5342 4906 4548
# ...

# %% [markdown]
# This column lists how many bikes were rented on a given day.
# This is a time-series(?) regression {probably}

# %% [markdown]
# ### Task 4

# %%
insurance_X = insurance_df.drop(columns='charges')
insurance_y = insurance_df['charges']
print('Insurance Feature Columns:', insurance_X.columns.to_list())

grad_X = grad_df.drop(columns='admit')
grad_y = grad_df['admit']
print('Grad Feature Columns:', grad_X.columns.to_list())

bike_sharing_X = bike_sharing_df.drop(columns=['cnt', 'casual', 'registered'])
bike_sharing_y = bike_sharing_df['cnt']
print('Bike Sharing Feature Columns:', bike_sharing_X.columns.to_list())
# Out:
# Insurance Feature Columns: ['age', 'sex', 'bmi', 'children', 'smoker', 'region']
# Grad Feature Columns: ['gre', 'gpa', 'rank']
# Bike Sharing Feature Columns: ['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed']

# %% [markdown]
# # Should we include 'casual' and registered' columns in either X or y ?? discuss.
